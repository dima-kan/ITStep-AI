# %% [markdown]
# <a href="https://colab.research.google.com/github/dima-kan/ITStep-AI/blob/superwised_learning/%D0%94%D0%97_%D0%BE%D0%B1%D1%80%D0%BE%D0%B1%D0%BA%D0%B0_%D0%B4%D0%B0%D0%BD%D0%B8%D1%851.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/House_Rent_Dataset.csv", index_col="Unnamed: 0")

# %% [markdown]
# [Інформація про дані](https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset)

# %%
df.head(30)
# Out:
#      Posted On  BHK     Rent    Size            Floor    Area Type  \
# 0   2022-05-18  2.0  10000.0  1100.0  Ground out of 2          NaN
# 1   2022-05-13  2.0  20000.0   800.0       1 out of 3   Super Area
# 2   2022-05-16  2.0  17000.0  1000.0       1 out of 3   Super Area
# 3   2022-07-04  2.0  10000.0   800.0       1 out of 2   Super Area
# 4          NaN  2.0   7500.0   850.0       1 out of 2  Carpet Area
# 5   2022-04-29  2.0   7000.0   600.0  Ground out of 1   Super Area
# 6   2022-06-21  2.0  10000.0   700.0  Ground out of 4   Super Area
# 7   2022-06-21  1.0   5000.0   250.0       1 out of 2   Super Area
# 8   2022-06-07  2.0  26000.0   800.0       1 out of 2  Carpet Area
# 9   2022-06-20  2.0      NaN  1000.0       1 out of 3  Carpet Area
# 10  2022-05-23  3.0  25000.0  1200.0       1 out of 4  Carpet Area
# 11  2022-06-07  1.0   5000.0   400.0       1 out of 1  Carpet Area
# 12  2022-05-14  1.0   6500.0   250.0       1 out of 4  Carpet Area
# 13  2022-05-09  1.0   5500.0     NaN       1 out of 2  Carpet Area
# 14  2022-05-05  3.0   8500.0   900.0  Ground out of 2          NaN
# 15  2022-06-01  3.0      NaN  1286.0       1 out of 1  Carpet Area
# 16  2022-05-17  2.0   6000.0   600.0       1 out of 2   Super Area
# 17  2022-06-20  2.0  10000.0   800.0  Ground out of 2   Super Area
# 18  2022-06-09  2.0  11000.0  2000.0  Ground out of 3  Carpet Area
# 19         NaN  2.0   6000.0   660.0       1 out of 2   Super Area
# 20  2022-07-02  NaN   7900.0   650.0              NaN  Carpet Area
# 21  2022-06-14  2.0   9000.0   400.0       2 out of 3          NaN
# 22         NaN  1.0   4000.0   300.0  Ground out of 4  Carpet Area
# 23  2022-06-15  3.0   6500.0  1600.0  Ground out of 2   Super Area
# 24  2022-05-28  1.0   8000.0   400.0       1 out of 2   Super Area
# 25  2022-05-22  2.0   7000.0  1000.0       1 out of 1   Super Area
# 26  2022-06-18  1.0   5300.0   355.0       1 out of 1  Carpet Area
# 27  2022-06-25  2.0   6000.0  1000.0  Ground out of 3   Super Area
# 28  2022-06-22  2.0   8500.0   800.0       4 out of 5   Super Area
# 29  2022-06-25  NaN  12500.0     NaN  Ground out of 2   Super Area
#
#                       Area Locality     City Furnishing Status  \
# 0                               NaN  Kolkata       Unfurnished
# 1          Phool Bagan, Kankurgachi  Kolkata    Semi-Furn
# 24         Bachelors       1.0    Contact Agent
# 25  Bachelors/Family       NaN              NaN
# 26  Bachelors/Family       1.0    Contact Agent
# 27  Bachelors/Family       1.0              NaN
# 28  Bachelors/Family       1.0    Contact Owner
# 29  Bachelors/Family       2.0    Contact Owner

# %% [markdown]
# # Завдання 1
# Виведіть інформацію про таблицю(кількість рядків та стовпчиків та типи даних). Також виведіть кількість пропущених значень по стовпчиках

# %%
df.shape
# Out:
# (4746, 12)

# %%
df.isna().sum()
# Out:
# Posted On            367
# BHK                  404
# Rent                 377
# Size                 344
# Floor                366
# Area Type            356
# Area Locality        399
# City                 358
# Furnishing Status    351
# Tenant Preferred     374
# Bathroom             359
# Point of Contact     374
# dtype: int64

# %%
df.dtypes
# Out:
# Posted On             object
# BHK                  float64
# Rent                 float64
# Size                 float64
# Floor                 object
# Area Type             object
# Area Locality         object
# City                  object
# Furnishing Status     object
# Tenant Preferred      object
# Bathroom             float64
# Point of Contact      object
# dtype: object

# %% [markdown]
# # Завдання 2
# Виведіть гістограми для всіх числових стовпчиків

# %%
ax = df['BHK'].plot(kind='hist',    # тип діаграми hist
                             bins=30,        # кількість стовпчиків
                             figsize=(14,6)  # розмір зображення(в дюймах)
                             )


ax.set_ylabel('BHK')
ax.set_xlabel('amount')
# Out:
# Text(0.5, 0, 'amount')

# %%
ax = df['Rent'].plot(kind='hist',    # тип діаграми hist
                             bins=30,        # кількість стовпчиків
                             figsize=(14,6)  # розмір зображення(в дюймах)
                             )


ax.set_ylabel('Rent')
ax.set_xlabel('amount')
# Out:
# Text(0.5, 0, 'amount')

# %%
ax = df['Size'].plot(kind='hist',    # тип діаграми hist
                             bins=30,        # кількість стовпчиків
                             figsize=(14,6)  # розмір зображення(в дюймах)
                             )


ax.set_ylabel('Size')
ax.set_xlabel('amount')
# Out:
# Text(0.5, 0, 'amount')

# %%
ax = df['Bathroom'].plot(kind='hist',    # тип діаграми hist
                             bins=30,        # кількість стовпчиків
                             figsize=(14,6)  # розмір зображення(в дюймах)
                             )


ax.set_ylabel('Bathroom')
ax.set_xlabel('amount')
# Out:
# Text(0.5, 0, 'amount')

# %% [markdown]
# # Завдання 3
# Виведіть ящик з вусами для всіх числових стовпчиків. Де потрібно очистіть викиди

# %%
df['BHK'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (4078, 12)

# %%
mask = df['Rent'] < 100000
mask.sum()
# Out:
# np.int64(4078)

# %%
df = df[mask]

# %%
df['Rent'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
mask = df['Size'] < 2500
mask.sum()
# Out:
# np.int64(3735)

# %%
df = df[mask]

# %%
df['Size'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
df['Bathroom'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# # Завдання 4
# Створіть Pipeline для обробки даних
